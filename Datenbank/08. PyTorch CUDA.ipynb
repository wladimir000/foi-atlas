# %%
import sys

!"{sys.executable}" -m pip list | findstr torch
# Out:
# torch                                    2.11.0+cu128
# torchaudio                               2.11.0+cu128
# torchvision                              0.26.0+cu128

# %%
import sys
import subprocess

print("CPU-Version wird entfernt ...")

subprocess.run(
    [
        sys.executable,
        "-m",
        "pip",
        "uninstall",
        "-y",
        "torch",
        "torchvision",
        "torchaudio",
    ],
    check=False,
)

print("CUDA-Version wird installiert ...")

subprocess.run(
    [
        sys.executable,
        "-m",
        "pip",
        "install",
        "torch",
        "torchvision",
        "torchaudio",
        "--index-url",
        "https://download.pytorch.org/whl/cu128",
    ],
    check=True,
)

print("Installation abgeschlossen. Jetzt den Kernel neu starten.")
# Out:
# CPU-Version wird entfernt ...
# CUDA-Version wird installiert ...
# Installation abgeschlossen. Jetzt den Kernel neu starten.

# %%
import torch

print("=" * 50)
print("PyTorch-Version :", torch.__version__)
print("CUDA-Version    :", torch.version.cuda)
print("CUDA verfügbar  :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU             :", torch.cuda.get_device_name(0))
    print("Anzahl GPUs     :", torch.cuda.device_count())
    print(
        "VRAM            :",
        round(torch.cuda.get_device_properties(0).total_memory / 1024**3, 2),
        "GB",
    )
else:
    print("\n❌ CUDA wird nicht verwendet.")
    print("Wahrscheinlich ist die CPU-Version von PyTorch installiert.")
# Out:
# ...
# PyTorch-Version : 2.11.0+cu128
# CUDA-Version    : 12.8
# CUDA verfügbar  : True
# GPU             : NVIDIA GeForce RTX 3060 Ti
# Anzahl GPUs     : 1
# VRAM            : 8.0 GB
