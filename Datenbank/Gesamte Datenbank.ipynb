# %%
{
    "request": "https://fragdenstaat.de/api/v1/request/",
    "message": "https://fragdenstaat.de/api/v1/message/",
    "attachment": "https://fragdenstaat.de/api/v1/attachment/",
    "following": "https://fragdenstaat.de/api/v1/following/",
    "georegion": "https://fragdenstaat.de/api/v1/georegion/",
    "publicbody": "https://fragdenstaat.de/api/v1/publicbody/",
    "category": "https://fragdenstaat.de/api/v1/category/",
    "classification": "https://fragdenstaat.de/api/v1/classification/",
    "jurisdiction": "https://fragdenstaat.de/api/v1/jurisdiction/",
    "law": "https://fragdenstaat.de/api/v1/law/",
    "document": "https://fragdenstaat.de/api/v1/document/",
    "documentportal": "https://fragdenstaat.de/api/v1/documentportal/",
    "documentcollection": "https://fragdenstaat.de/api/v1/documentcollection/",
    "page": "https://fragdenstaat.de/api/v1/page/",
    "pageannotation": "https://fragdenstaat.de/api/v1/pageannotation/",
    "problemreport": "https://fragdenstaat.de/api/v1/problemreport/",
    "campaign": "https://fragdenstaat.de/api/v1/campaign/",
    "upload": "https://fragdenstaat.de/api/v1/upload/",
    "articletag": "https://fragdenstaat.de/api/v1/articletag/",
    "campaigninformationobject": "https://fragdenstaat.de/api/v1/campaigninformationobject/",
    "venue": "https://fragdenstaat.de/api/v1/venue/",
    "governmentplan": "https://fragdenstaat.de/api/v1/governmentplan/"
}
# Out:
# {'request': 'https://fragdenstaat.de/api/v1/request/',
#  'message': 'https://fragdenstaat.de/api/v1/message/',
#  'attachment': 'https://fragdenstaat.de/api/v1/attachment/',
#  'following': 'https://fragdenstaat.de/api/v1/following/',
#  'georegion': 'https://fragdenstaat.de/api/v1/georegion/',
#  'publicbody': 'https://fragdenstaat.de/api/v1/publicbody/',
#  'category': 'https://fragdenstaat.de/api/v1/category/',
#  'classification': 'https://fragdenstaat.de/api/v1/classification/',
#  'jurisdiction': 'https://fragdenstaat.de/api/v1/jurisdiction/',
#  'law': 'https://fragdenstaat.de/api/v1/law/',
#  'document': 'https://fragdenstaat.de/api/v1/document/',
#  'documentportal': 'https://fragdenstaat.de/api/v1/documentportal/',
#  'documentcollection': 'https://fragdenstaat.de/api/v1/documentcollection/',
#  'page': 'https://fragdenstaat.de/api/v1/page/',
#  'pageannotation': 'https://fragdenstaat.de/api/v1/pageannotation/',
# ...
